# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\ADMIN\\Downloads\\archive\\udemy_output_All_Finance__Accounting_p1_p626.csv')

# %%
df.head()
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3   648826         The Complete Financial Analyst Course 2020
# 4   637930  An Entire MBA in 1 Course:Award Winning Busine...
#
#                                                  url  is_paid  \
# 0                 /course/the-complete-sql-bootcamp/     True
# 1                                 /course/tableau10/     True
# 2                        /course/pmp-pmbok6-35-pdus/     True
# 3     /course/the-complete-financial-analyst-course/     True
# 4  /course/an-entire-mba-in-1-courseaward-winning...     True
#
#    num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0           295509     4.66019            4.67874  4.67874        78006
# ...

# %%
df.shape
# Out:
# (13608, 20)

# %%
plt.figure(figsize=(8,8))
sns.boxplot(df.is_paid,df.avg_rating)
plt.show()

# %%
df['num_subscribers'].value_counts()
# Out:
# 0        215
# 1        169
# 2        117
# 3         93
# 5         91
#         ...
# 1428       1
# 11665      1
# 3469       1
# 1420       1
# 6129       1
# Name: num_subscribers, Length: 4875, dtype: int64

# %%
df[df.is_paid==False]['num_subscribers'].value_counts()
# Out:
# 831      3
# 66       2
# 1106     2
# 401      2
# 409      2
#         ..
# 72       1
# 11925    1
# 4759     1
# 1688     1
# 1        1
# Name: num_subscribers, Length: 470, dtype: int64

# %%
sns.scatterplot(x=df[df.is_paid==True]['num_subscribers'],y=df[df.is_paid==True]['avg_rating'])
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x=df['num_subscribers'],y=df['avg_rating'],hue=df['is_paid'],alpha=0.3)
plt.show()

# %%
df['is_paid'].value_counts()
# Out:
# True     13112
# False      496
# Name: is_paid, dtype: int64

# %%
plt.figure(figsize=(20,10))
df['num_reviews'].value_counts().plot.line()

# %%
df['num_reviews'].value_counts().sort_index(ascending=False).head(20)
# Out:
# 78006    1
# 54581    1
# 52653    1
# 46447    1
# 41630    1
# 38093    1
# 30470    1
# 28665    1
# 27408    1
# 23906    1
# 23635    1
# 23580    1
# 23326    1
# 22595    1
# 21537    1
# 21436    1
# 21421    1
# 21394    1
# 20613    1
# 20538    1
# Name: num_reviews, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df['num_reviews'],y=df['avg_rating'],hue=df['is_paid'],alpha=0.3)
plt.show()

# %%
df.head(1)
# Out:
#        id                                              title  \
# 0  762616  The Complete SQL Bootcamp 2020: Go from Zero t...
#
#                                   url  is_paid  num_subscribers  avg_rating  \
# 0  /course/the-complete-sql-bootcamp/     True           295509     4.66019
#
#    avg_rating_recent   rating  num_reviews  is_wishlisted  \
# 0            4.67874  4.67874        78006          False
#
#    num_published_lectures  num_published_practice_tests               created  \
# 0                      84                             0  2016-02-14T22:57:48Z
#
#          published_time  discount_price__amount discount_price__currency  \
# 0  2016-04-06T05:16:11Z                   455.0                      INR
#
#   discount_price__price_string  price_detail__amount price_detail__currency  \
# 0                         ₹455                8640.0                    INR
#
#   price_detail__price_string
# 0                     ₹8,640

# %%
df['is_wishlisted'].value_counts()
# Out:
# False    13608
# Name: is_wishlisted, dtype: int64

# %%
df.shape
# Out:
# (13608, 20)

# %%
 df['num_published_lectures'].value_counts()
# Out:
# 10     518
# 11     491
# 12     447
# 9      444
# 8      409
#       ...
# 141      1
# 202      1
# 210      1
# 250      1
# 551      1
# Name: num_published_lectures, Length: 301, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x=df['num_published_lectures'],y=df['avg_rating'],hue=df['is_paid'],alpha=0.3)
plt.show()

# %%
df['num_published_practice_tests'].value_counts()
# Out:
# 0    13008
# 2      214
# 1      202
# 6       67
# 5       43
# 3       39
# 4       35
# Name: num_published_practice_tests, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.heatmap(pd.crosstab(df.is_paid,df.num_published_practice_tests),annot=True,fmt='g')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x=df['num_published_practice_tests'],y=df['avg_rating'],hue=df['is_paid'],alpha=0.3)
plt.show()

# %%
 df['created']
# Out:
# 0        2016-02-14T22:57:48Z
# 1        2016-08-22T12:10:18Z
# 2        2017-09-26T16:32:48Z
# 3        2015-10-23T13:34:35Z
# 4        2015-10-12T06:39:46Z
#                  ...
# 13603    2020-04-15T10:20:17Z
# 13604    2020-09-01T17:57:15Z
# 13605    2020-07-27T02:29:18Z
# 13606    2020-06-07T01:29:53Z
# 13607    2020-03-30T19:10:58Z
# Name: created, Length: 13608, dtype: object

# %%
df['created'].dtype
# Out:
# dtype('O')

# %%
pd.to_datetime(df['created'],format='%Y-%m-%dT%H:%M:%SZ')
# Out:
# 0       2016-02-14 22:57:48
# 1       2016-08-22 12:10:18
# 2       2017-09-26 16:32:48
# 3       2015-10-23 13:34:35
# 4       2015-10-12 06:39:46
#                 ...
# 13603   2020-04-15 10:20:17
# 13604   2020-09-01 17:57:15
# 13605   2020-07-27 02:29:18
# 13606   2020-06-07 01:29:53
# 13607   2020-03-30 19:10:58
# Name: created, Length: 13608, dtype: datetime64[ns]

# %%
df['year_series']=pd.to_datetime(df['created'],format='%Y-%m-%dT%H:%M:%SZ').dt.year

# %%
df.head(2)
# Out:
#        id                                              title  \
# 0  762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1  937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
#
#                                   url  is_paid  num_subscribers  avg_rating  \
# 0  /course/the-complete-sql-bootcamp/     True           295509     4.66019
# 1                  /course/tableau10/     True           209070     4.58956
#
#    avg_rating_recent   rating  num_reviews  is_wishlisted  ...  \
# 0            4.67874  4.67874        78006          False  ...
# 1            4.60015  4.60015        54581          False  ...
#
#    num_published_practice_tests               created        published_time  \
# 0                             0  2016-02-14T22:57:48Z  2016-04-06T05:16:11Z
# 1                             0  2016-08-22T12:10:18Z  2016-08-23T16:59:49Z
#
#   discount_price__amount  discount_price__currency  \
# 0                  455.0                       INR
# ...

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x=df['year_series'],y=df['avg_rating'],hue=df['is_paid'],alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x=df['year_series'],y=df['avg_rating'])
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x=df['year_series'],y=df['num_subscribers'])
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x=df['year_series'],y=df['num_subscribers'],showfliers=False)
plt.show()

# %%
df['year_series_2']=pd.to_datetime(df['published_time'],format='%Y-%m-%dT%H:%M:%SZ').dt.year

# %%
df.head(2)
# Out:
#        id                                              title  \
# 0  762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1  937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
#
#                                   url  is_paid  num_subscribers  avg_rating  \
# 0  /course/the-complete-sql-bootcamp/     True           295509     4.66019
# 1                  /course/tableau10/     True           209070     4.58956
#
#    avg_rating_recent   rating  num_reviews  is_wishlisted  ...  \
# 0            4.67874  4.67874        78006          False  ...
# 1            4.60015  4.60015        54581          False  ...
#
#                 created        published_time discount_price__amount  \
# 0  2016-02-14T22:57:48Z  2016-04-06T05:16:11Z                  455.0
# 1  2016-08-22T12:10:18Z  2016-08-23T16:59:49Z                  455.0
#
#   discount_price__currency  discount_price__price_string price_detail__amount  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x=df['year_series_2'],y=df['avg_rating'])
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x=df['year_series_2'],y=df['num_subscribers'],showfliers=False)
plt.show()

# %%
df['discount_price__amount']
# Out:
# 0        455.0
# 1        455.0
# 2        455.0
# 3        455.0
# 4        455.0
#          ...
# 13603      NaN
# 13604      NaN
# 13605      NaN
# 13606      NaN
# 13607      NaN
# Name: discount_price__amount, Length: 13608, dtype: float64

# %%
df['price_detail__amount']
# Out:
# 0        8640.0
# 1        8640.0
# 2        8640.0
# 3        8640.0
# 4        8640.0
#           ...
# 13603       NaN
# 13604       NaN
# 13605       NaN
# 13606       NaN
# 13607       NaN
# Name: price_detail__amount, Length: 13608, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(y=df['discount_price__amount'],x=df['price_detail__amount'],hue=(df['discount_price__amount']<1000))
plt.show()

# %%
df.head(2)
# Out:
#        id                                              title  \
# 0  762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1  937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
#
#                                   url  is_paid  num_subscribers  avg_rating  \
# 0  /course/the-complete-sql-bootcamp/     True           295509     4.66019
# 1                  /course/tableau10/     True           209070     4.58956
#
#    avg_rating_recent   rating  num_reviews  is_wishlisted  ...  \
# 0            4.67874  4.67874        78006          False  ...
# 1            4.60015  4.60015        54581          False  ...
#
#                 created        published_time discount_price__amount  \
# 0  2016-02-14T22:57:48Z  2016-04-06T05:16:11Z                  455.0
# 1  2016-08-22T12:10:18Z  2016-08-23T16:59:49Z                  455.0
#
#   discount_price__currency  discount_price__price_string price_detail__amount  \
# ...

# %%
df.shape
# Out:
# (13608, 22)

# %%
df.columns
# Out:
# Index(['id', 'title', 'url', 'is_paid', 'num_subscribers', 'avg_rating',
#        'avg_rating_recent', 'rating', 'num_reviews', 'is_wishlisted',
#        'num_published_lectures', 'num_published_practice_tests', 'created',
#        'published_time', 'discount_price__amount', 'discount_price__currency',
#        'discount_price__price_string', 'price_detail__amount',
#        'price_detail__currency', 'price_detail__price_string', 'year_series',
#        'year_series_2'],
#       dtype='object')

# %%
df.discount_price__currency.value_counts()
# Out:
# INR    12205
# Name: discount_price__currency, dtype: int64

# %%
df.price_detail__currency.value_counts()
# Out:
# INR    13111
# Name: price_detail__currency, dtype: int64

# %%
df['Percent_discount']=((df['price_detail__amount']-df['discount_price__amount'])/df['price_detail__amount']*100)

# %%
plt.figure(figsize=(20,10))
((df['price_detail__amount']-df['discount_price__amount'])/df['price_detail__amount']*100).plot.hist(color='green')
plt.xlabel('Percentage of discount')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.boxplot(df['price_detail__amount'])
plt.show()

# %%
plt.figure(figsize=(20,10))
df[df.Percent_discount>=90]['price_detail__amount'].value_counts().plot.bar()
plt.show()

# %%
plt.figure(figsize=(20,10))
df[df.avg_rating<3][df.Percent_discount>=60]['price_detail__amount'].value_counts().plot.bar(stacked=True)
df[df.avg_rating>3][df.Percent_discount>=60]['price_detail__amount'].value_counts().plot.bar(stacked=True)
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\ADMIN\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
